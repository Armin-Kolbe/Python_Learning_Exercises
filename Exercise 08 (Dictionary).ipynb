# %% [markdown]
# <div style="color: white;padding-top:18px;text-align:center;background-color:#610C9F;border-radius:15px;border: 1px solid white;">
#     <h3>Exercise 8 (Dictionary)</h3>
# </div>

# %% [markdown]
# <div style="color: white;padding-top:18px;text-align:left;background-color:#940B92;border-radius:15px;border: 1px solid white;">
#     <h4>Question 01</h4>
# <p>
# Below list is information of a product, change this list to dictionary and
# answer to questions?
# <p style= "margin-left: 30px"> product = ['Apple iPhone', 999.99, 'Space Gray', 'July 2021']</p>
# </p>
# <ol>
# <li>
# What is the name of the product?
# </li>
# <li>
# What is the price of the product?
# </li>
# <li>
# What is the color of the product?</li>
# <li>
# When was the product released?
# </li>
# <li>
# Can you change the color of the product to 'Silver'?
# </li>
# <li>
# Create a list with 4 products by this structure.
# </li>
# </ol>
# </div>

# %% [markdown]
# من چون منظور سوال سال شش را به چندين فرم متوجه شدم و نميدانم كدام مد نظر استاد است, جواب سال شش را به چندين فرم خروجى دادم

# %% [markdown]
# ### Alternative 1

# %%
product = ['Apple iPhone', 999.99, 'Space Gray', 'July 2021']
title = ['name', 'price', 'color', 'released_date']
product_dic = {}

product_dic = dict(map(lambda i,j : (i,j) , title, product))

print("1. The name of the product is: ", product_dic["name"])
print("2. The price of the product is: ", product_dic["price"])
print("3. The color of the product is: ", product_dic["color"])
print("4. The released date is: ", product_dic["released_date"])
product_dic["color"] = "Silver"
print("5. The new color of the product is: ", product_dic["color"])

# Question 6 First and second Alternative 

product_dict1 = {"name1": "n1", "price1": 1, "color1": "c1", "released date1": "d1"}
product_dict2 = {"name2": "n2", "price2": 2, "color2": "c2", "released date2": "d2"}
product_dict3 = {"name3": "n3", "price3": 3, "color3": "c3", "released date3": "d3"}
product_dict4 = {"name4": "n4", "price4": 4, "color4": "c4", "released date4": "d4"}

# 1. Alternative

products_dict = {}
products_dict.update(product_dict1)
products_dict.update(product_dict2)
products_dict.update(product_dict3)
products_dict.update(product_dict4)
print("6. A Dictionary with 4 prodaucts: ", products_dict)

products_list = []
for key, value in products_dict.items():
    temp = (key,value)
    products_list.append(temp)
print("6. A List with 4 products: ", products_list)

# 2. Alternative

product_list_total = [product_dict1, product_dict2, product_dict3, product_dict1]
print("6. A List with 4 products: ", product_list_total)
# Out:
# 1. The name of the product is:  Apple iPhone
# 2. The price of the product is:  999.99
# 3. The color of the product is:  Space Gray
# 4. The released date is:  July 2021
# 5. The new color of the product is:  Silver
# 6. A Dictionary with 4 prodaucts:  {'name1': 'n1', 'price1': 1, 'color1': 'c1', 'released date1': 'd1', 'name2': 'n2', 'price2': 2, 'color2': 'c2', 'released date2': 'd2', 'name3': 'n3', 'price3': 3, 'color3': 'c3', 'released date3': 'd3', 'name4': 'n4', 'price4': 4, 'color4': 'c4', 'released date4': 'd4'}
# 6. A List with 4 products:  [('name1', 'n1'), ('price1', 1), ('color1', 'c1'), ('released date1', 'd1'), ('name2', 'n2'), ('price2', 2), ('color2', 'c2'), ('released date2', 'd2'), ('name3', 'n3'), ('price3', 3), ('color3', 'c3'), ('released date3', 'd3'), ('name4', 'n4'), ('price4', 4), ('color4', 'c4'), ('released date4', 'd4')]
# ...

# %%
# Question 6 in different outputs

product_list1 = ["name1", 111.1, "color1", "released date1"]
product_list2 = ["name2", 222.2, "color2", "released date2"]
product_list3 = ["name3", 333.3, "color3", "released date3"]
product_list4 = ["name4", 444.4, "color4", "released date4"]

products_all1 = []
products_all2 = []
products_all3 = []
tmp1 = []
tmp2 = []
products_names = []
products_prices = []
products_colors = []
products_released_dates = []

for i in range(len(product_list1)):
    products_all1.append(product_list1[i])
    products_all1.append(product_list2[i])
    products_all1.append(product_list3[i])
    products_all1.append(product_list4[i])

products_all2 = product_list1 + product_list2 + product_list3 + product_list4

tmp1 = list(zip(product_list1 , product_list2))
tmp2 = list(zip(product_list3 , product_list4))
products_all3 = list(zip(tmp1 , tmp2))

a = len(product_list1)
for i in range(a):
    products_names.append(products_all1[i])
for j in range(a,2*a,1):
    products_prices.append(products_all1[j])
for k in range(2*a,3*a,1):
    products_colors.append(products_all1[k])
for l in range(3*a,4*a,1):
    products_released_dates.append(products_all1[l])

print("6.1 A List with all products: ", products_all1)
print("6.2 A List with all products: ", products_all2)
print("6.3 A List with all products: ", products_all3)




print("6.4.1 A List with all names: ", products_names)
print("6.4.2 A List with all prices: ", products_prices)
print("6.4.3 A List with all colors: ", products_colors)
print("6.4.4 A List with all released dates: ", products_released_dates)


# Alternative 7: 4 Products as 1 Dictionary
prducts_dictionary1 = {"name" : ["n1", "n2", "n3", "n4"],
                      "price" : [11.1, 22.2, 33.3, 44.4],
                      "colors" : ["c1", "c2", "c3", "c4"],
                      "release_date" : ["rd1", "rd2", "rd3", "rd4"]
                     }
print("7. A List with all as dictionary: ", prducts_dictionary1)

# Alternative 8: 4 Products as 1 List
p_d1 = {"name" : "n1","price" : 11.1,"colors" : "c1","release_date" : "rd1"}
p_d2 = {"name" : "n1","price" : 22.2,"colors" : "c2","release_date" : "rd2"}
p_d3 = {"name" : "n3","price" : 33.3,"colors" : "c3","release_date" : "rd3"}
p_d4 = {"name" : "n4","price" : 44.4,"colors" : "c4","release_date" : "rd4"}
product_dictionary2 = {}

product_total = [p_d1, p_d2, p_d3, p_d4]
print("8. All products as List", product_total)
# Out:
# 6.1 A List with all products:  ['name1', 'name2', 'name3', 'name4', 111.1, 222.2, 333.3, 444.4, 'color1', 'color2', 'color3', 'color4', 'released date1', 'released date2', 'released date3', 'released date4']
# 6.2 A List with all products:  ['name1', 111.1, 'color1', 'released date1', 'name2', 222.2, 'color2', 'released date2', 'name3', 333.3, 'color3', 'released date3', 'name4', 444.4, 'color4', 'released date4']
# 6.3 A List with all products:  [(('name1', 'name2'), ('name3', 'name4')), ((111.1, 222.2), (333.3, 444.4)), (('color1', 'color2'), ('color3', 'color4')), (('released date1', 'released date2'), ('released date3', 'released date4'))]
# 6.4.1 A List with all names:  ['name1', 'name2', 'name3', 'name4']
# 6.4.2 A List with all prices:  [111.1, 222.2, 333.3, 444.4]
# 6.4.3 A List with all colors:  ['color1', 'color2', 'color3', 'color4']
# 6.4.4 A List with all released dates:  ['released date1', 'released date2', 'released date3', 'released date4']
# ...

# %% [markdown]
# <div style="color: white;padding-top:18px;text-align:left;background-color:#940B92;border-radius:15px;border: 1px solid white;">
#     <h4>Question 02</h4>
# <p>
# create a dictionary named `student_grades` containing three students' names
# as keys and their grades as values. Perform the following:
# </p>
# <ul>
# <li>
# add two new students with their grades to `student_grades`, names are unique.
# </li>
# <li>
# Delete any students from `student_grades` who have grades below 10.
# </li>
# <li>
# Get a name from the user If the user's name is in the dictionary of students, get
# a new grade and change the student's grade.</li>
# <li>
# Show the average scores of all students.
# </li>
# </ul>
# </div>

# %%
student_grades = {
                  1:{"name":"n1","grade": 12.5},
                  2:{"name":"n2","grade": 17.5},
                  3:{"name":"n3","grade": 8.5},
                }
print("before add: ", student_grades)

student_grades.update({4:{"name":"n4","grade": 15.5}})
student_grades.update({5:{"name":"n5","grade": 9.5}})
print("after add: ", student_grades)

l=[]
for i in range(len(student_grades)):
    if student_grades[i+1]["grade"] < 10 :
       del student_grades[i+1]
       l.append(i+1)
print("Students with grade greater as 10: ", student_grades)

for i in range(len(l)):
   student_grades.update({l[i]:{"name": "","grade": -1}})

c = 0
new_student = input("please enter student's name: ")
for i in range (len(student_grades)):
   if new_student in student_grades[i+1]["name"]:
      a = student_grades[i+1]["name"]
      student_grades[i+1]["grade"] = input(f"please enter new grade for {a}: ")
      c+=1
if c == 0:
   print(f"There is no one with this name: {new_student}")
else:
   for i in l:
      del student_grades[i]
   print("After change the grade of student in dict", student_grades)

a = len(student_grades)
for i in range(len(l)):
   student_grades.update({l[i]:{"name": "","grade": 0}})
sum = 0
for i in range(len(student_grades)):
   sum += float(student_grades[i+1]["grade"])
print("The Average scores: ", sum/a)
# Out:
# before add:  {1: {'name': 'n1', 'grade': 12.5}, 2: {'name': 'n2', 'grade': 17.5}, 3: {'name': 'n3', 'grade': 8.5}}
# after add:  {1: {'name': 'n1', 'grade': 12.5}, 2: {'name': 'n2', 'grade': 17.5}, 3: {'name': 'n3', 'grade': 8.5}, 4: {'name': 'n4', 'grade': 15.5}, 5: {'name': 'n5', 'grade': 9.5}}
# Students with grade greater as 10:  {1: {'name': 'n1', 'grade': 12.5}, 2: {'name': 'n2', 'grade': 17.5}, 4: {'name': 'n4', 'grade': 15.5}}
# After change the grade of student in dict {1: {'name': 'n1', 'grade': 12.5}, 2: {'name': 'n2', 'grade': 17.5}, 4: {'name': 'n4', 'grade': '3'}}
# The Average scores:  11.0
